# %% [markdown]
# # 光學文字辨識(Optical Character Recognition, OCR)

# %% [markdown]
# ## 載入相關套件

# %%
# 載入相關套件
import cv2 
import pytesseract
import matplotlib.pyplot as plt

# %% [markdown]
# ## 載入並顯示圖檔

# %%
# 載入圖檔
image = cv2.imread('./images_ocr/receipt.png')

# 顯示圖檔
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %% [markdown]
# ## OCR 辨識

# %%
# 參數設定
custom_config = r'--psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# Welcome to Mel's
# Check #: 0001 12/20/11
# Server: Jesh F 4:38 PM
# Table: 7/1 Guests: 2
# 2 Beef Burgr (€9.95/ea) 19,90
# SIDE: Fries
#
# 1 Bud Light 3.79
# 1 Bud 4.50
# Sub-total 28.19
# Sales Tax 2.50
# TOTAL 30.69
# Balance Due 30.69
#
# Thank you for your patronage! a

# %% [markdown]
# ## 只辨識數字

# %%
# 參數設定，只辨識數字
custom_config = r'--psm 6 outputbase digits'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# 0001 122011
# 4338-
# 71 2
# 29.95 19.90
# 1 3.79
# 1 4.50
# - 28.19
# 2.50
# 0 30.69
# 30.69

# %% [markdown]
# ## 只辨識有限字元

# %%
# 參數設定白名單，只辨識有限字元
custom_config = r'-c tessedit_char_whitelist=abcdefghijklmnopqrstuvwxyz --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# elcometoels
# heck
# erverdeshf
# able uests
# eefurgrea
# efries
#
# udight
# ud
# ubtotal
# alesfax
# a
# alanceue
#
# hankyouforyourpatronage a

# %% [markdown]
# ## 設定黑名單，只辨識有限字元

# %%
# 參數設定黑名單，只辨識有限字元
custom_config = r'-c tessedit_char_blacklist=abcdefghijklmnopqrstuvwxyz --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# W  M]'
# C #: 0001 12/20/11
# S: J F 4:38 PM
# T: 7/1 G: 2
# 2 B B (€9.95/) 19,90
# SIDE: F
#
# 1 B L 3.79
# 1 B 4.50
# S-] 28.19
# S T 2.50
# TOTAL 30.69
# BI D 30.69
#
# T  é! ‘

# %% [markdown]
# ## 辨識多國文字

# %% [markdown]
# ## 載入並顯示圖檔

# %%
# 載入圖檔
image = cv2.imread('./images_ocr/chinese.png')

# 顯示圖檔
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %%
# 辨識多國文字，中文繁體、日文及英文
custom_config = r'-l chi_tra+jpn+eng --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# Tesseract OCR 是 目 前 律 盛 行 的 OCR BRAS HP 公 司 炎 ⑳0⑤ 年 開 放 原 始 程 式 磋 (Open
# Source) ・ 以 C﹢﹢ 開 發 而 成 的 ， 可 由 原 始 程 式 碼 建 置 安 裝 ， 或 直 接 安 裝 已 建 置 奸 的
# 程 式 ， 我 們 採 取 後 者 ， 先 自 https:/eithub.com/UB-Mannheim/tesseract/wiki 下 載 最 新
# 版 exe 檔 ， 直 掩 執 行 即 可 ， 安 裝 完 成 後 ， 將 安 裝 路 徐 下 bin 子 目 錄 放 入 環 境 變 數
# Path 内 ・ 若 要 以 Python 呼 叫 Tesseract OCR ・ 需 額 外 安 襄 pytesseract 套 件 ， 指 令 知
# 下 ﹕
#
# pip install pytesseract

# %% [markdown]
# ## 辨識多國文字

# %% [markdown]
# ## 載入並顯示圖檔

# %%
# 載入圖檔
image = cv2.imread('./images_ocr/chinese_2.png')

# 顯示圖檔
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,6))
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %%
# 辨識多國文字，中文繁體、日文及英文
custom_config = r'-l chi_tra+jpn+eng --psm 6'
# OCR 辨識
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# Tesseract OCR 是 目 前 律 盛 行 的 OCR BRAS HP 公 司 炎 ⑳0⑤ 年 開 放 原 始 程 式 磋 (Open
# Source) ・ 以 C﹢﹢ 開 發 而 成 的 ， 可 由 原 始 程 式 碼 建 置 安 裝 ， 或 直 接 安 裝 已 建 置 奸 的
# 程 式 ， 我 們 採 取 後 者 ， 先 自 https:/eithub.com/UB-Mannheim/tesseract/wiki 下 載 最 新
# 版 exe 檔 ， 直 掩 執 行 即 可 ， 安 裝 完 成 後 ， 將 安 裝 路 徐 下 bin 子 目 錄 放 入 環 境 變 數
# Path 内 ・ 若 要 以 Python 呼 叫 Tesseract OCR ・ 需 額 外 安 襄 pytesseract 套 件 ， 指 令 知
# 下 ﹕
#
# pip install pytesseract
