# %% [markdown]
# ##  [YOLOV5 in PyTorch](https://pytorch.org/hub/ultralytics_yolov5/)

# %% [markdown]
# ## 载入套件

# %%
import torch

# %% [markdown]
# ## 检查 GPU

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
"cuda" if torch.cuda.is_available() else "cpu"
# Out:
# 'cuda'

# %% [markdown]
# ## 载入模型

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True).to(device)
# Out:
# Using cache found in C:\Users\mikec/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2021-11-4 torch 1.10.0+cu113 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4096MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# ## 预测

# %%
# 批次处理
imgs = ['https://ultralytics.com/images/zidane.jpg', 
        './images_Object_Detection/car.jpg']  

# 预测
results = model(imgs)

# 输出结果
results.print()
# Out:
# image 1/2: 720x1280 2 persons, 1 tie
# image 2/2: 2139x3500 10 cars
# Speed: 665.5ms pre-process, 86.1ms inference, 161.3ms NMS per image at shape (2, 3, 416, 640)

# %% [markdown]
# ## 预测结果存档

# %%
results.save()
# Out:
# Saved 2 images to runs\detect\exp

# %% [markdown]
# ## 显示结果

# %%
results.show()

# %%
from IPython.display import Image
Image('./runs/detect/exp/zidane.jpg')

# %% [markdown]
# ## 显示定界框及预测机率

# %%
results.xyxy[0]
# Out:
# tensor([[7.54500e+02, 3.92500e+01, 1.14200e+03, 7.13000e+02, 8.76465e-01, 0.00000e+00],
#         [1.24000e+02, 1.99875e+02, 9.58000e+02, 7.10500e+02, 5.62500e-01, 0.00000e+00],
#         [4.40500e+02, 4.27500e+02, 5.00500e+02, 7.16500e+02, 5.20020e-01, 2.70000e+01]], device='cuda:0')

# %% [markdown]
# ## 以表格显示定界框、预测机率及类别

# %%
results.pandas().xyxy[0]
# Out:
#      xmin    ymin    xmax   ymax  confidence  class    name
# 0  752.00   45.75  1148.0  716.0    0.875977      0  person
# 1  100.25  201.50  1001.0  718.5    0.572266      0  person
# 2  438.50  422.25   510.0  720.0    0.525879     27     tie
